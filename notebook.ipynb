#  '1_8_2_1_1',
#  '1_8_3_1_1',
#  '1_8_3_2_2',
# ...

# %%
import zipfile
from typing import Generator, Dict, Tuple
import json



# Open the ZIP file
def file_content()-> Generator[Tuple[str, Dict], None, None]:
    with zipfile.ZipFile('tennisviz_take_home_task_data.zip', 'r') as zip_ref:
        # List all files inside
        file_list = zip_ref.namelist()
        for file_name in sort_files(file_list):
            
            # Read the content of each file
            with zip_ref.open(f"data/{file_name}.json") as file:
                content = file.read()
                data = json.loads(content)
                
                yield file_name, data

# %%
rows = []
match = None
players = None
for index, file_content in enumerate(files_content()):
    name, data = file_content
    if index == 0:
        match = data["match"]
        players = {player["team"]: player for player in match["players"]}

    sequences = data["sequences"]
    hits, bounces = [], []
    for sample in data["samples"]:
        if sample.get("event") == "hit":
            hits.append(sample)
        if sample.get("event") == "bounce":
            bounces.append(sample) 
            
    for shot in data["shots"]:
        shot_n = shot["shot_no"]
        if shot_n > len(hits):
            continue
        timestamp  = shot["time_utc"]
        duration = shot["duration"]
        start_time = datetime.strptime(timestamp, "%Y-%m-%dT%H:%M:%S.%fZ")

        end_time = (start_time + timedelta(seconds=duration)).isoformat() + "Z"
        time = shot["time"]

        hit = hits[shot_n-1]
        bounce = next((x for x in bounces if hit["time"] < x["time"] < hit["time"] + duration ),None)
        hit_players_positions = sorted(hit["players"],key=lambda x: x["team"]==shot["team"], reverse=True)

        hit_ball = hit["ball"]["pos"]
        bounce_ball = bounce["ball"]["pos"] if bounce else {"x": "", "y": ""}
        row = {
            "season": match["season"],
            "tournament_id": match["tournament_id"],
            "draw_code": match["draw_code"],
            "set": sequences["set"],
            "game": sequences["game"],
            "point": sequences["point"],
            "serve": sequences["serve"],
            "rally": sequences["rally"],
            "shot_n": shot_n,
            "hitter_external_id": players[shot["team"]]["external_id"],
            "stroke": shot["stroke"],
            "spin_type": shot["spin"]["type"],
            "spin_rpm": shot["spin"]["rpm"],
            "call": shot["call"],
            "shot_start_timestamp": timestamp,
            "shot_end_timestamp": end_time,
            "ball_hit_x": hit_ball["x"],
            "ball_hit_y": hit_ball["y"],
            "ball_hit_z": hit_ball["z"],
            "ball_bounce_x": bounce_ball["x"],
            "ball_bounce_y": bounce_ball["y"],
            "hitter_x": hit_players_positions[0]["pos"]["x"],
            "hitter_y": hit_players_positions[0]["pos"]["y"],
            "receiver_x": hit_players_positions[1]["pos"]["x"],
            "receiver_y": hit_players_positions[1]["pos"]["y"],
        }
        rows.append(row)

# %%
import csv
with open('result.csv', mode='w', newline='') as file:
    fieldnames = list(rows[0].keys())
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerows(rows)

# %%
import pandas as pd

df = pd.read_csv('result.csv')

# %%
df.head(10)
# Out:
#    season  tournament_id draw_code  set  game  point  serve  rally  shot_n  \
# 0    2025           9999     MS001    1     1      1      1      1       1
# 1    2025           9999     MS001    1     1      1      1      1       2
# 2    2025           9999     MS001    1     1      2      1      1       1
# 3    2025           9999     MS001    1     1      2      1      1       2
# 4    2025           9999     MS001    1     1      2      1      1       3
# 5    2025           9999     MS001    1     1      3      1      1       1
# 6    2025           9999     MS001    1     1      4      1      1       1
# 7    2025           9999     MS001    1     1      4      2      2       1
# 8    2025           9999     MS001    1     1      4      2      2       2
# 9    2025           9999     MS001    1     1      4      2      2       3
#
#   hitter_external_id  ...           shot_end_timestamp ball_hit_x  ball_hit_y  \
# ...
